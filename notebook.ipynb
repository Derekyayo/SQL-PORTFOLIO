# %% [markdown]
# ## 1. The oldest business in the world
# <p><img src="https://assets.datacamp.com/production/repositories/5851/datasets/7dded924c6dc418d4a828f2f4daba99953c27a5a/400px-Eingang_zum_St._Peter_Stiftskeller.jpg" alt="The entrance to St. Peter Stiftskeller, a restaurant in Saltzburg, Austria. The sign over the entrance shows &quot;803&quot; - the year the business opened."></p>
# <p><em>Image: St. Peter Stiftskeller, founded 803. Credit: <a href="https://commons.wikimedia.org/wiki/File:Eingang_zum_St._Peter_Stiftskeller.jpg">Pakeha</a>.</em></p>
# <p>An important part of business is planning for the future and ensuring that the company survives changing market conditions. Some businesses do this really well and last for hundreds of years.</p>
# <p>BusinessFinancing.co.uk <a href="https://businessfinancing.co.uk/the-oldest-company-in-almost-every-country">researched</a> the oldest company that is still in business in (almost) every country and compiled the results into a dataset. In this project, you'll explore that dataset to see what they found.</p>
# <p>The database contains three tables.</p>
# <h3 id="categories"><code>categories</code></h3>
# <table>
# <thead>
# <tr>
# <th style="text-align:left;">column</th>
# <th>type</th>
# <th>meaning</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align:left;"><code>category_code</code></td>
# <td>varchar</td>
# <td>Code for the category of the business.</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>category</code></td>
# <td>varchar</td>
# <td>Description of the business category.</td>
# </tr>
# </tbody>
# </table>
# <h3 id="countries"><code>countries</code></h3>
# <table>
# <thead>
# <tr>
# <th style="text-align:left;">column</th>
# <th>type</th>
# <th>meaning</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align:left;"><code>country_code</code></td>
# <td>varchar</td>
# <td>ISO 3166-1 3-letter country code.</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>country</code></td>
# <td>varchar</td>
# <td>Name of the country.</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>continent</code></td>
# <td>varchar</td>
# <td>Name of the continent that the country exists in.</td>
# </tr>
# </tbody>
# </table>
# <h3 id="businesses"><code>businesses</code></h3>
# <table>
# <thead>
# <tr>
# <th style="text-align:left;">column</th>
# <th>type</th>
# <th>meaning</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align:left;"><code>business</code></td>
# <td>varchar</td>
# <td>Name of the business.</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>year_founded</code></td>
# <td>int</td>
# <td>Year the business was founded.</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>category_code</code></td>
# <td>varchar</td>
# <td>Code for the category of the business.</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>country_code</code></td>
# <td>char</td>
# <td>ISO 3166-1 3-letter country code.</td>
# </tr>
# </tbody>
# </table>
# <p>Let's begin by looking at the range of the founding years throughout the world.</p>

# %%
# %%sql
# postgresql:///oldestbusinesses
#
# -- Select the oldest and newest founding years from the businesses table
# SELECT min(year_founded),
# max(year_founded)
# FROM businesses;
# Out:
# 1 rows affected.
# [(578, 1999)]

# %% [markdown]
# ## 2. How many businesses were founded before 1000?
# <p>Wow! That's a lot of variation between countries. In one country, the oldest business was only founded in 1999. By contrast, the oldest business in the world was founded back in 578. That's pretty incredible that a business has survived for more than a millennium.</p>
# <p>I wonder how many other businesses there are like that.</p>

# %%
# %%sql
#
# -- Get the count of rows in businesses where the founding year was before 1000
# SELECT COUNT(*)
# FROM businesses
# WHERE year_founded < 1000;
# Out:
#  * postgresql:///oldestbusinesses
# 1 rows affected.
# [(6,)]

# %% [markdown]
# ## 3. Which businesses were founded before 1000?
# <p>Having a count is all very well, but I'd like more detail. Which businesses have been around for more than a millennium?</p>

# %%
# %%sql
#
# -- Select all columns from businesses where the founding year was before 1000
# -- Arrange the results from oldest to newest
# SELECT *
# FROM businesses
# WHERE year_founded < 1000
# ORDER BY year_founded;
# Out:
#  * postgresql:///oldestbusinesses
# 6 rows affected.
# [('Kongō Gumi', 578, 'CAT6', 'JPN'),
#  ('St. Peter Stifts Kulinarium', 803, 'CAT4', 'AUT'),
#  ('Staffelter\xa0Hof Winery', 862, 'CAT9', 'DEU'),
#  ('Monnaie de Paris\xa0', 864, 'CAT12', 'FRA'),
#  ('The Royal Mint', 886, 'CAT12', 'GBR'),
#  ("Sean's Bar", 900, 'CAT4', 'IRL')]

# %% [markdown]
# ## 4. Exploring the categories
# <p>Now we know that the oldest, continuously operating company in the world is called Kongō Gumi. But was does that company do? The category codes in the <code>businesses</code> table aren't very helpful: the descriptions of the categories are stored in the <code>categories</code> table.</p>
# <p>This is a common problem: for data storage, it's better to keep different types of data in different tables, but for analysis, you want all the data in one place. To solve this, you'll have to join the two tables together.</p>

# %%
# %%sql
#
# -- Select business name, founding year, and country code from businesses; and category from categories
# -- where the founding year was before 1000, arranged from oldest to newest
# SELECT bu.business,
#     bu.year_founded,
#     bu.country_code,
#     ca.category
# FROM businesses bu
# LEFT JOIN categories ca on ca.category_code = bu.category_code
# WHERE bu.year_founded < 1000
# ORDER BY bu.year_founded;
# Out:
#  * postgresql:///oldestbusinesses
# 6 rows affected.
# [('Kongō Gumi', 578, 'JPN', 'Construction'),
#  ('St. Peter Stifts Kulinarium', 803, 'AUT', 'Cafés, Restaurants & Bars'),
#  ('Staffelter\xa0Hof Winery', 862, 'DEU', 'Distillers, Vintners, & Breweries'),
#  ('Monnaie de Paris\xa0', 864, 'FRA', 'Manufacturing & Production'),
#  ('The Royal Mint', 886, 'GBR', 'Manufacturing & Production'),
#  ("Sean's Bar", 900, 'IRL', 'Cafés, Restaurants & Bars')]

# %% [markdown]
# ## 5. Counting the categories
# <p>With that extra detail about the oldest businesses, we can see that Kongō Gumi is a construction company. In that list of six businesses, we also see a café, a winery, and a bar. The two companies recorded as "Manufacturing and Production" are both mints. That is, they produce currency.</p>
# <p>I'm curious as to what other industries constitute the oldest companies around the world, and which industries are most common.</p>

# %%
# %%sql
#
# -- Select the category and count of category (as "n")
# -- arranged by descending count, limited to 10 most common categories
# SELECT ca.category,
# COUNT(bu.business) n
# FROM businesses bu
# LEFT JOIN categories ca on ca.category_code = bu.category_code
# GROUP BY 1
# ORDER BY 2 DESC
# LIMIT 10;
# Out:
#  * postgresql:///oldestbusinesses
# 10 rows affected.
# [('Banking & Finance', 37),
#  ('Distillers, Vintners, & Breweries', 22),
#  ('Aviation & Transport', 19),
#  ('Postal Service', 16),
#  ('Manufacturing & Production', 15),
#  ('Media', 7),
#  ('Agriculture', 6),
#  ('Cafés, Restaurants & Bars', 6),
#  ('Food & Beverages', 6),
#  ('Tourism & Hotels', 4)]

# %% [markdown]
# ## 6. Oldest business by continent
# <p>It looks like "Banking &amp; Finance" is the most popular category. Maybe that's where you should aim if you want to start a thousand-year business.</p>
# <p>One thing we haven't looked at yet is where in the world these really old businesses are. To answer these questions, we'll need to join the <code>businesses</code> table to the <code>countries</code> table. Let's start by asking how old the oldest business is on each continent.</p>

# %%
# %%sql
#
# -- Select the oldest founding year (as "oldest") from businesses,
# -- and continent from countries
# -- for each continent, ordered from oldest to newest
# SELECT  min(bu.year_founded) oldest,
#         cu.continent
# FROM businesses bu
# LEFT JOIN countries cu on cu.country_code = bu.country_code
# GROUP BY 2
# ORDER BY 1;
# Out:
#  * postgresql:///oldestbusinesses
# 6 rows affected.
# [(578, 'Asia'),
#  (803, 'Europe'),
#  (1534, 'North America'),
#  (1565, 'South America'),
#  (1772, 'Africa'),
#  (1809, 'Oceania')]

# %% [markdown]
# ## 7. Joining everything for further analysis
# <p>Interesting. There's a jump in time from the older businesses in Asia and Europe to the 16th Century oldest businesses in North and South America, then to the 18th and 19th Century oldest businesses in Africa and Oceania. </p>
# <p>As mentioned earlier, when analyzing data it's often really helpful to have all the tables you want access to joined together into a single set of results that can be analyzed further. Here, that means we need to join all three tables.</p>

# %%
# %%sql
#
# -- Select the business, founding year, category, country, and continent
# SELECT bu.business,
#     bu.year_founded,
#     ca.category,
#     cu country,
#     cu continent
# FROM businesses bu
# LEFT JOIN countries cu on cu.country_code = bu.country_code
# LEFT JOIN categories ca on ca.category_code = bu.category_code;
# Out:
#  * postgresql:///oldestbusinesses
# 163 rows affected.
# [('Spinzar Cotton Company', 1930, 'Agriculture', '(AFG,Afghanistan,Asia)', '(AFG,Afghanistan,Asia)'),
#  ('ALBtelecom', 1912, 'Telecommunications', '(ALB,Albania,Europe)', '(ALB,Albania,Europe)'),
#  ('Andbank', 1930, 'Banking & Finance', '(AND,Andorra,Europe)', '(AND,Andorra,Europe)'),
#  ('Liwa Chemicals', 1939, 'Manufacturing & Production', '(ARE,"United Arab Emirates",Asia)', '(ARE,"United Arab Emirates",Asia)'),
#  ('Bank of the Province of Buenos Aires', 1822, 'Banking & Finance', '(ARG,Argentina,"South America")', '(ARG,Argentina,"South America")'),
#  ('Yerevan Ararat Brandy-Wine-Vodka Factory', 1877, 'Distillers, Vintners, & Breweries', '(ARM,Armenia,Asia)', '(ARM,Armenia,Asia)'),
#  ('Australia Post', 1809, 'Postal Service', '(AUS,Australia,Oceania)', '(AUS,Australia,Oceania)'),
#  ('St. Peter Stifts Kulinarium', 803, 'Cafés, Restaurants & Bars', '(AUT,Austria,Europe)', '(AUT,Austria,Europe)'),
#  ('Azerbaijan Caspian Shipping Company', 1858, 'Aviation & Transport', '(AZE,Azerbaijan,Asia)', '(AZE,Azerbaijan,Asia)'),
#  ('Brarudi', 1955, 'Distillers, Vintners, & Breweries', '(BDI,Burundi,Africa)', '(BDI,Burundi,Africa)'),
#  ('Affligem Brewery', 1074, 'Distillers, Vintners, & Breweries', '(BEL,Belgium,Europe)', '(BEL,Belgium,Europe)'),
#  ('Communauté Électrique du Bénin', 1968, 'Energy', '(BEN,Benin,Africa)', '(BEN,Benin,Africa)'),
#  ('Air Burkina', 1967, 'Aviation & Transport', '(BFA,"Burkina Faso",Africa)', '(BFA,"Burkina Faso",Africa)'),
#  ('M. M. Ispahani Limited', 1820, 'Food & Beverages', '(BGD,Bangladesh,Asia)', '(BGD,Bangladesh,Asia)'),
#  ('Arsenal AD', 1878, 'Defense', '(BGR,Bulgaria,Europe)', '(BGR,Bulgaria,Europe)'),
#  ('BMMI', 1883, 'Retail', '(BHR,Bahrain,Asia)', '(BHR,Bahrain,Asia)'),
#  ('Sarajevska Pivara', 1864, 'Distillers, Vintners, & Breweries', '(BIH,"Bosnia and Herzegovina",Europe)', '(BIH,"Bosnia and Herzegovina",Europe)'),
#  ('Olivaria Brewery', 1864, 'Distillers, Vintners, & Breweries', '(BLR,Belarus,Europe)', '(BLR,Belarus,Europe)'),
#  ('Belize Bank', 1902, 'Banking & Finance', '(BLZ,Belize,"North America")', '(BLZ,Belize,"North America")'),
#  ('Banco Nacional de Bolivia', 1871, 'Banking & Finance', '(BOL,"Bolivia, Plurinational State of","South America")', '(BOL,"Bolivia, Plurinational State of","South America")'),
#  ('Casa da Moeda do Brasil', 1694, 'Manufacturing & Production', '(BRA,Brazil,"South America")', '(BRA,Brazil,"South America")'),
#  ('Mount Gay Rum', 1703, 'Distillers, Vintners, & Breweries', '(BRB,Barbados,"North America")', '(BRB,Barbados,"North America")'),
#  ('Hua Ho Department Store', 1947, 'Retail', '(BRN,"Brunei Darussalam",Asia)', '(BRN,"Brunei Darussalam",Asia)'),
#  ('Tashi Group', 1959, 'Aviation & Transport', '(BTN,Bhutan,Asia)', '(BTN,Bhutan,Asia)'),
#  ('Botswana Meat Commission', 1965, 'Agriculture', '(BWA,Botswana,Africa)', '(BWA,Botswana,Africa)'),
#  ('Banque Internationale pour la Centrafrique', 1946, 'Banking & Finance', '(CAF,"Central African Republic",Africa)', '(CAF,"Central African Republic",Africa)'),
#  ("Hudson's Bay Company", 1670, 'Retail', '(CAN,Canada,"North America")', '(CAN,Canada,"North America")'),
#  ('Gasthof Sternen', 1230, 'Tourism & Hotels', '(CHE,Switzerland,Europe)', '(CHE,Switzerland,Europe)'),
#  ('Famae', 1811, 'Defense', '(CHL,Chile,"South America")', '(CHL,Chile,"South America")'),
#  ("Ma Yu Ching's Bucket Chicken House", 1153, 'Cafés, Restaurants & Bars', '(CHN,China,Asia)', '(CHN,China,Asia)'),
#  ('La Poste', 1945, 'Postal Service', '(CIV,"Côte d\'Ivoire",Africa)', '(CIV,"Côte d\'Ivoire",Africa)'),
#  ('Cameroon Development Corporation', 1947, 'Agriculture', '(CMR,Cameroon,Africa)', '(CMR,Cameroon,Africa)'),
#  ('Société nationale des Chemins de fer du Congo', 1889, 'Aviation & Transport', '(COD,"Congo, The Democratic Republic of the",Africa)', '(COD,"Congo, The Democratic Republic of the",Africa)'),
#  ('Development Bank of the Central African States', 1975, 'Banking & Finance', '(COG,Congo,Africa)', '(COG,Congo,Africa)'),
#  ('Casa de Moneda de Colombia', 1621, 'Manufacturing & Production', '(COL,Colombia,"South America")', '(COL,Colombia,"South America")'),
#  ('Central Bank of the Comoros', 1981, 'Banking & Finance', '(COM,Comoros,Africa)', '(COM,Comoros,Africa)'),
#  ('Correios de Cabo Verde', 1849, 'Postal Service', '(CPV,"Cabo Verde",Africa)', '(CPV,"Cabo Verde",Africa)'),
#  ('Florida Ice and Farm Company', 1908, 'Distillers, Vintners, & Breweries', '(CRI,"Costa Rica","North America")', '(CRI,"Costa Rica","North America")'),
#  ('Cubana de Aviación', 1929, 'Aviation & Transport', '(CUB,Cuba,"North America")', '(CUB,Cuba,"North America")'),
#  ('Bank of Cyprus', 1899, 'Banking & Finance', '(CYP,Cyprus,Europe)', '(CYP,Cyprus,Europe)'),
#  ('Pivovar Broumov', 1348, 'Distillers, Vintners, & Breweries', '(CZE,Czechia,Europe)', '(CZE,Czechia,Europe)'),
#  ('Staffelter\xa0Hof Winery', 862, 'Distillers, Vintners, & Breweries', '(DEU,Germany,Europe)', '(DEU,Germany,Europe)'),
#  ('Ethio-Djibouti Railways', 1901, 'Aviation & Transport', '(DJI,Djibouti,Africa)', '(DJI,Djibouti,Africa)'),
#  ('The Chronicle (Dominica)', 1909, 'Media', '(DMA,Dominica,"North America")', '(DMA,Dominica,"North America")'),
#  ('Munke Mølle', 1135, 'Manufacturing & Production', '(DNK,Denmark,Europe)', '(DNK,Denmark,Europe)'),
#  ('Hamoud Boualem', 1878, 'Food & Beverages', '(DZA,Algeria,Africa)', '(DZA,Algeria,Africa)'),
#  ('Egyptian National Railways', 1854, 'Aviation & Transport', '(EGY,Egypt,Africa)', '(EGY,Egypt,Africa)'),
#  ('Asmara Brewery', 1939, 'Distillers, Vintners, & Breweries', '(ERI,Eritrea,Africa)', '(ERI,Eritrea,Africa)'),
#  ('Casa de Ganaderos', 1218, 'Agriculture', '(ESP,Spain,Europe)', '(ESP,Spain,Europe)'),
#  ('Raeapteek', 1422, 'Medical', '(EST,Estonia,Europe)', '(EST,Estonia,Europe)'),
#  ('National Bank of Ethiopia', 1906, 'Banking & Finance', '(ETH,Ethiopia,Africa)', '(ETH,Ethiopia,Africa)'),
#  ('Fiskars', 1649, 'Consumer Goods', '(FIN,Finland,Europe)', '(FIN,Finland,Europe)'),
#  ('Monnaie de Paris\xa0', 864, 'Manufacturing & Production', '(FRA,France,Europe)', '(FRA,France,Europe)'),
#  ('BGFIBank Group', 1971, 'Banking & Finance', '(GAB,Gabon,Africa)', '(GAB,Gabon,Africa)'),
#  ('The Royal Mint', 886, 'Manufacturing & Production', '(GBR,"United Kingdom",Europe)', '(GBR,"United Kingdom",Europe)'),
#  ('Bank of Georgia', 1903, 'Banking & Finance', '(GEO,Georgia,Asia)', '(GEO,Georgia,Asia)'),
#  ('Halco Mining', 1962, 'Mining', '(GIN,Guinea,Africa)', '(GIN,Guinea,Africa)'),
#  ('Correios da Guiné-Bissau', 1973, 'Postal Service', '(GNB,Guinea-Bissau,Africa)', '(GNB,Guinea-Bissau,Africa)'),
#  ('Guinea Ecuatorial Airlines', 1996, 'Aviation & Transport', '(GNQ,"Equatorial Guinea",Africa)', '(GNQ,"Equatorial Guinea",Africa)'),
#  ('Piraeus Bank', 1606, 'Banking & Finance', '(GRC,Greece,Europe)', '(GRC,Greece,Europe)'),
#  ('Corporación Multi Inversiones', 1920, 'Food & Beverages', '(GTM,Guatemala,"North America")', '(GTM,Guatemala,"North America")'),
#  ('Banks DIH', 1840, 'Food & Beverages', '(GUY,Guyana,"South America")', '(GUY,Guyana,"South America")'),
#  ('National Railroad of Honduras', 1870, 'Aviation & Transport', '(HND,Honduras,"North America")', '(HND,Honduras,"North America")'),
#  ('Kraljevica Shipyard', 1729, 'Manufacturing & Production', '(HRV,Croatia,Europe)', '(HRV,Croatia,Europe)'),
#  ('Rhum Barbancourt', 1862, 'Distillers, Vintners, & Breweries', '(HTI,Haiti,"North America")', '(HTI,Haiti,"North America")'),
#  ('Zwack', 1790, 'Distillers, Vintners, & Breweries', '(HUN,Hungary,Europe)', '(HUN,Hungary,Europe)'),
#  ('Pindad', 1808, 'Defense', '(IDN,Indonesia,Asia)', '(IDN,Indonesia,Asia)'),
#  ('Wadia Group', 1736, 'Manufacturing & Production', '(IND,India,Asia)', '(IND,India,Asia)'),
#  ("Sean's Bar", 900, 'Cafés, Restaurants & Bars', '(IRL,Ireland,Europe)', '(IRL,Ireland,Europe)'),
#  ('North Oil Company', 1928, 'Energy', '(IRQ,Iraq,Asia)', '(IRQ,Iraq,Asia)'),
#  ('Íslandspóstur', 1776, 'Postal Service', '(ISL,Iceland,Europe)', '(ISL,Iceland,Europe)'),
#  ('Café Abu Salem', 1914, 'Cafés, Restaurants & Bars', '(ISR,Israel,Asia)', '(ISR,Israel,Asia)'),
#  ('Marinelli Bell Foundry', 1040, 'Manufacturing & Production', '(ITA,Italy,Europe)', '(ITA,Italy,Europe)'),
#  ('Rose Hall', 1770, 'Tourism & Hotels', '(JAM,Jamaica,"North America")', '(JAM,Jamaica,"North America")'),
#  ('Arab Bank', 1930, 'Banking & Finance', '(JOR,Jordan,Asia)', '(JOR,Jordan,Asia)'),
#  ('Kongō Gumi', 578, 'Construction', '(JPN,Japan,Asia)', '(JPN,Japan,Asia)'),
#  ('Bogatyr Access Komir', 1913, 'Mining', '(KAZ,Kazakhstan,Asia)', '(KAZ,Kazakhstan,Asia)'),
#  ('KCB Group Limited', 1896, 'Banking & Finance', '(KEN,Kenya,Africa)', '(KEN,Kenya,Africa)'),
#  ('National Bank of Cambodia', 1954, 'Banking & Finance', '(KHM,Cambodia,Asia)', '(KHM,Cambodia,Asia)'),
#  ('KT Corporation', 1885, 'Telecommunications', '(KOR,"Korea, Republic of",Asia)', '(KOR,"Korea, Republic of",Asia)'),
#  ('M.H. Alshaya Co.', 1890, 'Retail', '(KWT,Kuwait,Asia)', '(KWT,Kuwait,Asia)'),
#  ('Electricite du Laos', 1959, 'Energy', '(LAO,"Lao People\'s Democratic Republic",Asia)', '(LAO,"Lao People\'s Democratic Republic",Asia)'),
#  ('Bank Audi', 1830, 'Banking & Finance', '(LBN,Lebanon,Asia)', '(LBN,Lebanon,Asia)'),
#  ('National Port Authority', 1921, 'Aviation & Transport', '(LBR,Liberia,Africa)', '(LBR,Liberia,Africa)'),
#  ('Umma Bank', 1907, 'Banking & Finance', '(LBY,Libya,Africa)', '(LBY,Libya,Africa)'),
#  ('1st National Bank of St Lucia', 1938, 'Banking & Finance', '(LCA,"Saint Lucia","North America")', '(LCA,"Saint Lucia","North America")'),
#  ('National Bank of Liechtenstein', 1861, 'Banking & Finance', '(LIE,Liechtenstein,Europe)', '(LIE,Liechtenstein,Europe)'),
#  ('George Steuart Group', 1835, 'Food & Beverages', '(LKA,"Sri Lanka",Asia)', '(LKA,"Sri Lanka",Asia)'),
#  ('Central Bank of Lesotho', 1978, 'Banking & Finance', '(LSO,Lesotho,Africa)', '(LSO,Lesotho,Africa)'),
#  ('Gubernija', 1665, 'Distillers, Vintners, & Breweries', '(LTU,Lithuania,Europe)', '(LTU,Lithuania,Europe)'),
#  ('Mousel', 1511, 'Distillers, Vintners, & Breweries', '(LUX,Luxembourg,Europe)', '(LUX,Luxembourg,Europe)'),
#  ('Cēsu Alus', 1590, 'Distillers, Vintners, & Breweries', '(LVA,Latvia,Europe)', '(LVA,Latvia,Europe)'),
#  ('Attijariwafa Bank', 1904, 'Banking & Finance', '(MAR,Morocco,Africa)', '(MAR,Morocco,Africa)'),
#  ('Air Madagascar', 1962, 'Aviation & Transport', '(MDG,Madagascar,Africa)', '(MDG,Madagascar,Africa)'),
#  ('La Casa de Moneda de México', 1534, 'Manufacturing & Production', '(MEX,Mexico,"North America")', '(MEX,Mexico,"North America")'),
#  ('Tutunski kombinat Prilep', 1873, 'Consumer Goods', '(MKD,"North Macedonia",Europe)', '(MKD,"North Macedonia",Europe)'),
#  ('Office de Radiodiffusion-Télévision du Mali', 1957, 'Media', '(MLI,Mali,Africa)', '(MLI,Mali,Africa)'),
#  ('HSBC Bank Malta', 1882, 'Banking & Finance', '(MLT,Malta,Europe)', '(MLT,Malta,Europe)'),
#  ('Myanmar National Airlines', 1948, 'Aviation & Transport', '(MMR,Myanmar,Asia)', '(MMR,Myanmar,Asia)'),
#  ('Pošta Crne Gore', 1841, 'Postal Service', '(MNE,Montenegro,Europe)', '(MNE,Montenegro,Europe)'),
#  ('Mongolian National Broadcaster', 1931, 'Media', '(MNG,Mongolia,Asia)', '(MNG,Mongolia,Asia)'),
#  ('Beira Railroad Corporation', 1892, 'Aviation & Transport', '(MOZ,Mozambique,Africa)', '(MOZ,Mozambique,Africa)'),
#  ('Central Bank of Mauritania', 1973, 'Banking & Finance', '(MRT,Mauritania,Africa)', '(MRT,Mauritania,Africa)'),
#  ('Mauritius Post', 1772, 'Postal Service', '(MUS,Mauritius,Africa)', '(MUS,Mauritius,Africa)'),
#  ('Malawi Broadcasting Corporation', 1964, 'Media', '(MWI,Malawi,Africa)', '(MWI,Malawi,Africa)'),
#  ('Pos Malaysia', 1800, 'Postal Service', '(MYS,Malaysia,Asia)', '(MYS,Malaysia,Asia)'),
#  ('NamPost', 1814, 'Postal Service', '(NAM,Namibia,Africa)', '(NAM,Namibia,Africa)'),
#  ('Office of Radio and Television of Niger', 1960, 'Media', '(NER,Niger,Africa)', '(NER,Niger,Africa)'),
#  ('First Bank of Nigeria', 1894, 'Banking & Finance', '(NGA,Nigeria,Africa)', '(NGA,Nigeria,Africa)'),
#  ('Flor de Caña', 1890, 'Distillers, Vintners, & Breweries', '(NIC,Nicaragua,"North America")', '(NIC,Nicaragua,"North America")'),
#  ('The Brand Brewery', 1340, 'Distillers, Vintners, & Breweries', '(NLD,Netherlands,Europe)', '(NLD,Netherlands,Europe)'),
#  ('Posten Norge', 1647, 'Postal Service', '(NOR,Norway,Europe)', '(NOR,Norway,Europe)'),
#  ('Nepal Bank Limited', 1937, 'Banking & Finance', '(NPL,Nepal,Asia)', '(NPL,Nepal,Asia)'),
#  ('Bank of New Zealand', 1861, 'Banking & Finance', '(NZL,"New Zealand",Oceania)', '(NZL,"New Zealand",Oceania)'),
#  ('Petroleum Development Oman', 1937, 'Energy', '(OMN,Oman,Asia)', '(OMN,Oman,Asia)'),
#  ('House of Habib', 1841, 'Conglomerate', '(PAK,Pakistan,Asia)', '(PAK,Pakistan,Asia)'),
#  ('National Bank of Panama', 1904, 'Banking & Finance', '(PAN,Panama,"North America")', '(PAN,Panama,"North America")'),
#  ('Casa Nacional de Moneda', 1565, 'Banking & Finance', '(PER,Peru,"South America")', '(PER,Peru,"South America")'),
#  ('Destileria Limtuaco', 1853, 'Distillers, Vintners, & Breweries', '(PHL,Philippines,Asia)', '(PHL,Philippines,Asia)'),
#  ('Bochnia Salt Mine', 1248, 'Mining', '(POL,Poland,Europe)', '(POL,Poland,Europe)'),
#  ("Kim Chong-t'ae Electric Locomotive Works", 1945, 'Aviation & Transport', '(PRK,"Korea, Democratic People\'s Republic of",Asia)', '(PRK,"Korea, Democratic People\'s Republic of",Asia)'),
#  ('CTT-Correios de Portugal SA', 1520, 'Postal Service', '(PRT,Portugal,Europe)', '(PRT,Portugal,Europe)'),
#  ('Salam International Investment Limited', 1952, 'Conglomerate', '(QAT,Qatar,Asia)', '(QAT,Qatar,Asia)'),
#  ('Ursus Breweries', 1878, 'Distillers, Vintners, & Breweries', '(ROU,Romania,Europe)', '(ROU,Romania,Europe)'),
#  ('Petrodvorets Watch Factory', 1721, 'Consumer Goods', '(RUS,"Russian Federation",Europe)', '(RUS,"Russian Federation",Europe)'),
#  ('National Post Office', 1922, 'Postal Service', '(RWA,Rwanda,Africa)', '(RWA,Rwanda,Africa)'),
#  ('House of Alireza', 1845, 'Construction', '(SAU,"Saudi Arabia",Asia)', '(SAU,"Saudi Arabia",Asia)'),
#  ('Bank of Khartoum', 1913, 'Banking & Finance', '(SDN,Sudan,Africa)', '(SDN,Sudan,Africa)'),
#  ('Dakar–Niger Railway', 1924, 'Aviation & Transport', '(SEN,Senegal,Africa)', '(SEN,Senegal,Africa)'),
#  ('Singapore Post', 1819, 'Postal Service', '(SGP,Singapore,Asia)', '(SGP,Singapore,Asia)'),
#  ('Rokel Commercial Bank', 1917, 'Banking & Finance', '(SLE,"Sierra Leone",Africa)', '(SLE,"Sierra Leone",Africa)'),
#  ('HSBC El Salvador', 1891, 'Banking & Finance', '(SLV,"El Salvador","North America")', '(SLV,"El Salvador","North America")'),
#  ('Radio Mogadishu', 1943, 'Media', '(SOM,Somalia,Africa)', '(SOM,Somalia,Africa)'),
#  ('Apatin Brewery', 1756, 'Distillers, Vintners, & Breweries', '(SRB,Serbia,Europe)', '(SRB,Serbia,Europe)'),
#  ('Ivory Bank', 1994, 'Banking & Finance', '(SSD,"South Sudan",Africa)', '(SSD,"South Sudan",Africa)'),
#  ('Central Bank of São Tomé and Príncipe', 1975, 'Banking & Finance', '(STP,"Sao Tome and Principe",Africa)', '(STP,"Sao Tome and Principe",Africa)'),
#  ('Kremnica Mint', 1328, 'Manufacturing & Production', '(SVK,Slovakia,Europe)', '(SVK,Slovakia,Europe)'),
#  ('Gostilna Gastuž', 1467, 'Tourism & Hotels', '(SVN,Slovenia,Europe)', '(SVN,Slovenia,Europe)'),
#  ('Skyllbergs bruk', 1346, 'Manufacturing & Production', '(SWE,Sweden,Europe)', '(SWE,Sweden,Europe)'),
#  ('Swazi Rail', 1963, 'Aviation & Transport', '(SWZ,Eswatini,Africa)', '(SWZ,Eswatini,Africa)'),
#  ('Air Seychelles', 1977, 'Aviation & Transport', '(SYC,Seychelles,Asia)', '(SYC,Seychelles,Asia)'),
#  ('Bakdash', 1885, 'Cafés, Restaurants & Bars', '(SYR,"Syrian Arab Republic",Asia)', '(SYR,"Syrian Arab Republic",Asia)'),
#  ('Cotontchad', 1971, 'Agriculture', '(TCD,Chad,Africa)', '(TCD,Chad,Africa)'),
#  ('La Poste du Togo', 1883, 'Postal Service', '(TGO,Togo,Africa)', '(TGO,Togo,Africa)'),
#  ('B.Grimm Group', 1878, 'Conglomerate', '(THA,Thailand,Asia)', '(THA,Thailand,Asia)'),
#  ('House of Angostura', 1830, 'Distillers, Vintners, & Breweries', '(TTO,"Trinidad and Tobago","North America")', '(TTO,"Trinidad and Tobago","North America")'),
#  ('La Poste Tunisienne', 1847, 'Postal Service', '(TUN,Tunisia,Africa)', '(TUN,Tunisia,Africa)'),
#  ('Çemberlitaş Hamamı', 1584, 'Tourism & Hotels', '(TUR,Turkey,Asia)', '(TUR,Turkey,Asia)'),
#  ('Bank of Taiwan', 1897, 'Banking & Finance', '(TWN,"Taiwan, Province of China",Asia)', '(TWN,"Taiwan, Province of China",Asia)'),
#  ('Tanzania Breweries Limited', 1933, 'Distillers, Vintners, & Breweries', '(TZA,"Tanzania, United Republic of",Africa)', '(TZA,"Tanzania, United Republic of",Africa)'),
#  ('Stanbic Bank Uganda Limited', 1906, 'Banking & Finance', '(UGA,Uganda,Africa)', '(UGA,Uganda,Africa)'),
#  ('Drohobych salt plant', 1250, 'Manufacturing & Production', '(UKR,Ukraine,Europe)', '(UKR,Ukraine,Europe)'),
#  ('Cafe Brasilero', 1877, 'Cafés, Restaurants & Bars', '(URY,Uruguay,"South America")', '(URY,Uruguay,"South America")'),
#  ('Shirley Plantation', 1638, 'Agriculture', '(USA,"United States","North America")', '(USA,"United States","North America")'),
#  ('Tashkent Aviation Production Association', 1932, 'Manufacturing & Production', '(UZB,Uzbekistan,Asia)', '(UZB,Uzbekistan,Asia)'),
#  ('Hacienda Chuao', 1660, 'Food & Beverages', '(VEN,"Venezuela, Bolivarian Republic of","South America")', '(VEN,"Venezuela, Bolivarian Republic of","South America")'),
#  ('Vietnam Railways', 1881, 'Aviation & Transport', '(VNM,"Viet Nam",Asia)', '(VNM,"Viet Nam",Asia)'),
#  ('European Trust Company', 1991, 'Banking & Finance', '(VUT,Vanuatu,Oceania)', '(VUT,Vanuatu,Oceania)'),
#  ('Yemenia Airways', 1962, 'Aviation & Transport', '(YEM,Yemen,Asia)', '(YEM,Yemen,Asia)'),
#  ('Premier FMCG', 1820, 'Manufacturing & Production', '(ZAF,"South Africa",Africa)', '(ZAF,"South Africa",Africa)'),
#  ('ZamPost', 1896, 'Postal Service', '(ZMB,Zambia,Africa)', '(ZMB,Zambia,Africa)'),
#  ('Standard Chartered Zimbabwe', 1892, 'Banking & Finance', '(ZWE,Zimbabwe,Africa)', '(ZWE,Zimbabwe,Africa)'),
#  ('Meridian Corporation', 1999, 'Media', '("XK ",Kosovo,Europe)', '("XK ",Kosovo,Europe)')]

# %% [markdown]
# ## 8. Counting categories by continent
# <p>Having <code>businesses</code> joined to <code>categories</code> and <code>countries</code> together means we can ask questions about both these things together. For example, which are the most common categories for the oldest businesses on each continent?</p>

# %%
# %%sql
#
# -- Count the number of businesses in each continent and category
# SELECT cu.continent,
#     ca.category,
#     COUNT(distinct bu.business) n
# FROM businesses bu
# LEFT JOIN countries cu on cu.country_code = bu.country_code
# LEFT JOIN categories ca on ca.category_code = bu.category_code
# GROUP BY 1,2
# ORDER BY 1,2, 3 DESC;
# Out:
#  * postgresql:///oldestbusinesses
# 56 rows affected.
# [('Africa', 'Agriculture', 3),
#  ('Africa', 'Aviation & Transport', 10),
#  ('Africa', 'Banking & Finance', 17),
#  ('Africa', 'Distillers, Vintners, & Breweries', 3),
#  ('Africa', 'Energy', 1),
#  ('Africa', 'Food & Beverages', 1),
#  ('Africa', 'Manufacturing & Production', 1),
#  ('Africa', 'Media', 4),
#  ('Africa', 'Mining', 1),
#  ('Africa', 'Postal Service', 9),
#  ('Asia', 'Agriculture', 1),
#  ('Asia', 'Aviation & Transport', 7),
#  ('Asia', 'Banking & Finance', 6),
#  ('Asia', 'Cafés, Restaurants & Bars', 3),
#  ('Asia', 'Conglomerate', 3),
#  ('Asia', 'Construction', 2),
#  ('Asia', 'Defense', 1),
#  ('Asia', 'Distillers, Vintners, & Breweries', 2),
#  ('Asia', 'Energy', 3),
#  ('Asia', 'Food & Beverages', 2),
#  ('Asia', 'Manufacturing & Production', 3),
#  ('Asia', 'Media', 1),
#  ('Asia', 'Mining', 1),
#  ('Asia', 'Postal Service', 2),
#  ('Asia', 'Retail', 3),
#  ('Asia', 'Telecommunications', 1),
#  ('Asia', 'Tourism & Hotels', 1),
#  ('Europe', 'Agriculture', 1),
#  ('Europe', 'Banking & Finance', 5),
#  ('Europe', 'Cafés, Restaurants & Bars', 2),
#  ('Europe', 'Consumer Goods', 3),
#  ('Europe', 'Defense', 1),
#  ('Europe', 'Distillers, Vintners, & Breweries', 12),
#  ('Europe', 'Manufacturing & Production', 8),
#  ('Europe', 'Media', 1),
#  ('Europe', 'Medical', 1),
#  ('Europe', 'Mining', 1),
#  ('Europe', 'Postal Service', 4),
#  ('Europe', 'Telecommunications', 1),
#  ('Europe', 'Tourism & Hotels', 2),
#  ('North America', 'Agriculture', 1),
#  ('North America', 'Aviation & Transport', 2),
#  ('North America', 'Banking & Finance', 4),
#  ('North America', 'Distillers, Vintners, & Breweries', 5),
#  ('North America', 'Food & Beverages', 1),
#  ('North America', 'Manufacturing & Production', 1),
#  ('North America', 'Media', 1),
#  ('North America', 'Retail', 1),
#  ('North America', 'Tourism & Hotels', 1),
#  ('Oceania', 'Banking & Finance', 2),
#  ('Oceania', 'Postal Service', 1),
#  ('South America', 'Banking & Finance', 3),
#  ('South America', 'Cafés, Restaurants & Bars', 1),
#  ('South America', 'Defense', 1),
#  ('South America', 'Food & Beverages', 2),
#  ('South America', 'Manufacturing & Production', 2)]

# %% [markdown]
# ## 9. Filtering counts by continent and category
# <p>Combining continent and business category led to a lot of results. It's difficult to see what is important. To trim this down to a manageable size, let's restrict the results to only continent/category pairs with a high count.</p>

# %%
# %%sql
#
# -- Repeat that previous query, filtering for results having a count greater than 5
# with cte1 as(
# SELECT cu.continent,
#     ca.category,
#     COUNT(distinct bu.business) n
# FROM businesses bu
# LEFT JOIN countries cu on cu.country_code = bu.country_code
# LEFT JOIN categories ca on ca.category_code = bu.category_code
# GROUP BY 1,2
# ORDER BY 1,2, 3 DESC)
# SELECT *
# FROM cte1
# WHERE n > 5
# ORDER BY n DESC;
# Out:
#  * postgresql:///oldestbusinesses
# 7 rows affected.
# [('Africa', 'Banking & Finance', 17),
#  ('Europe', 'Distillers, Vintners, & Breweries', 12),
#  ('Africa', 'Aviation & Transport', 10),
#  ('Africa', 'Postal Service', 9),
#  ('Europe', 'Manufacturing & Production', 8),
#  ('Asia', 'Aviation & Transport', 7),
#  ('Asia', 'Banking & Finance', 6)]
